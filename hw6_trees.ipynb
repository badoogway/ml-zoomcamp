# %%
housing_link = 'https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv'
housing_output_path = 'housing.csv'


# !wget $housing_link -O $housing_output_path
# Out:
# --2023-10-21 10:25:53--  https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1423529 (1.4M) [text/plain]
# Saving to: ‘housing.csv’
#
# housing.csv         100%[===================>]   1.36M  --.-KB/s    in 0.01s
#
# 2023-10-21 10:25:53 (142 MB/s) - ‘housing.csv’ saved [1423529/1423529]

# %% [markdown]
# *Preparing the Dataset*

# %%
import pandas as pd

housing = pd.read_csv(housing_output_path)
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
import numpy as np

# Filter out the rows
mask = housing['ocean_proximity'].isin(['<1H OCEAN', 'INLAND'])
housing = housing[mask]

# Fill missing values
housing.fillna(0, inplace=True)

# Apply log transformation to the target column
housing['median_house_value'] = np.log(housing['median_house_value'])

housing.head()
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 701    -121.97     37.64                32.0       1283.0           194.0
# 830    -121.99     37.61                 9.0       3666.0           711.0
# 859    -121.97     37.57                21.0       4342.0           783.0
# 860    -121.96     37.58                15.0       3575.0           597.0
# 861    -121.98     37.58                20.0       4126.0          1031.0
#
#      population  households  median_income  median_house_value ocean_proximity
# 701       485.0       171.0         6.0574           12.973863       <1H OCEAN
# 830      2341.0       703.0         4.6458           12.287653       <1H OCEAN
# 859      2172.0       789.0         4.6146           12.419570       <1H OCEAN
# 860      1777.0       559.0         5.7192           12.554967       <1H OCEAN
# 861      2079.0       975.0         3.6832           12.287192       <1H OCEAN

# %%
from sklearn.model_selection import train_test_split

df_train_full, df_test = train_test_split(
    housing,
    test_size=0.2,
    random_state=1
)

df_train, df_valid = train_test_split(
    df_train_full,
    test_size=0.25,
    random_state=1
)

# %%
from sklearn.feature_extraction import DictVectorizer

dv = DictVectorizer(sparse=True)

X_train_full = df_train_full.drop('median_house_value', axis=1)
y_train_full = df_train_full['median_house_value'].values

X_train = df_train.drop('median_house_value', axis=1).to_dict(orient='records')
X_valid = df_valid.drop('median_house_value', axis=1).to_dict(orient='records')
X_test = df_test.drop('median_house_value', axis=1).to_dict(orient='records')

X_train = dv.fit_transform(X_train)
X_valid = dv.transform(X_valid)
X_test = dv.transform(X_test)

y_train = df_train['median_house_value'].values
y_valid = df_valid['median_house_value'].values
y_test = df_test['median_house_value'].values

# %% [markdown]
# **Question 1**

# %%
from sklearn.tree import DecisionTreeRegressor, export_text

dt = DecisionTreeRegressor(max_depth=1)
dt.fit(X_train, y_train)

print(export_text(dt, feature_names=dv.feature_names_))
# Out:
# |--- ocean_proximity=INLAND <= 0.50
# |   |--- value: [12.30]
# |--- ocean_proximity=INLAND >  0.50
# |   |--- value: [11.61]

# %% [markdown]
# **Question 2**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

rf = RandomForestRegressor(n_estimators=10, random_state=1, n_jobs=-1)
rf.fit(X_train, y_train)

round(mean_squared_error(y_valid, rf.predict(X_valid), squared=False), 3)
# Out:
# 0.245

# %% [markdown]
# **Question 3**

# %%
n_estimators = range(10, 200 + 1, 10)
errors = list()

for n in n_estimators:
    rf = RandomForestRegressor(n_estimators=n, random_state=1, n_jobs=-1)
    rf.fit(X_train, y_train)

    y_pred = rf.predict(X_valid)
    error = round(mean_squared_error(y_valid, y_pred, squared=False), 3)

    errors.append((n, error))

df_errors = pd.DataFrame(errors, columns=['n_estimators', 'RMSE'])
df_errors
# Out:
#     n_estimators   RMSE
# 0             10  0.245
# 1             20  0.239
# 2             30  0.237
# 3             40  0.236
# 4             50  0.236
# 5             60  0.235
# 6             70  0.235
# 7             80  0.235
# 8             90  0.235
# 9            100  0.234
# 10           110  0.234
# 11           120  0.234
# 12           130  0.234
# 13           140  0.234
# 14           150  0.233
# 15           160  0.233
# 16           170  0.233
# 17           180  0.233
# 18           190  0.234
# 19           200  0.234

# %% [markdown]
# **Question 4**

# %%
n_estimators = range(10, 200 + 1, 10)
max_depths = [10, 15, 20, 25]
errors = list()

for max_depth in max_depths:
    for n in n_estimators:
        rf = RandomForestRegressor(
            n_estimators=n, max_depth=max_depth,
            random_state=1, n_jobs=-1
        )
        rf.fit(X_train, y_train)

        y_pred = rf.predict(X_valid)
        error = mean_squared_error(y_valid, y_pred, squared=False)

        errors.append((max_depth, n, error))

df_errors = pd.DataFrame(errors, columns=['max_depth', 'n_estimators', 'RMSE'])
df_errors.sort_values(by='RMSE')
# Out:
#     max_depth  n_estimators      RMSE
# 56         20           170  0.233310
# 55         20           160  0.233369
# 76         25           170  0.233406
# 75         25           160  0.233408
# 57         20           180  0.233506
# ..        ...           ...       ...
# 4          10            50  0.245289
# 7          10            80  0.245379
# 2          10            30  0.246079
# 1          10            20  0.247320
# 0          10            10  0.250382
#
# [80 rows x 3 columns]

# %% [markdown]
# **Question 5**

# %%
rf = RandomForestRegressor(
    n_estimators=10, max_depth=20, random_state=1, n_jobs=-1
)
rf.fit(X_train, y_train)

df_feature_importances = pd.DataFrame(
    zip(rf.feature_importances_, dv.feature_names_),
    columns=['feature_importance', 'feature_name']
)
df_feature_importances.sort_values(by='feature_importance', ascending=False)
# Out:
#    feature_importance               feature_name
# 6            0.366280     ocean_proximity=INLAND
# 4            0.335320              median_income
# 2            0.101279                   latitude
# 3            0.086834                  longitude
# 1            0.030134         housing_median_age
# 7            0.027851                 population
# 9            0.021493                total_rooms
# 8            0.015465             total_bedrooms
# 0            0.015343                 households
# 5            0.000000  ocean_proximity=<1H OCEAN

# %% [markdown]
# **Question 6**

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.11.3)

# %%
import xgboost as xgb

dtrain = xgb.DMatrix(X_train, label=y_train)
dvalid = xgb.DMatrix(X_valid, label=y_valid)

watchlist = [(dtrain, 'train'), (dvalid, 'validation')]

# %%
xgb_num_rounds = 100
xgb_params = {
    'eta': 0.3,
    'max_depth': 6,
    'min_child_weight': 1,

    'objective': 'reg:squarederror',
    'nthread': 8,

    'seed': 1,
    'verbosity': 1,
}

model_eta3 = xgb.train(xgb_params, dtrain, xgb_num_rounds, evals=watchlist)
# Out:
# [0]	train-rmse:0.44351	validation-rmse:0.44250
# [1]	train-rmse:0.36600	validation-rmse:0.36917
# [2]	train-rmse:0.31556	validation-rmse:0.32383
# [3]	train-rmse:0.28541	validation-rmse:0.29965
# [4]	train-rmse:0.26573	validation-rmse:0.28418
# [5]	train-rmse:0.25338	validation-rmse:0.27463
# [6]	train-rmse:0.24157	validation-rmse:0.26770
# [7]	train-rmse:0.23486	validation-rmse:0.26423
# [8]	train-rmse:0.22668	validation-rmse:0.25820
# [9]	train-rmse:0.21996	validation-rmse:0.25444
# [10]	train-rmse:0.21445	validation-rmse:0.25179
# [11]	train-rmse:0.21155	validation-rmse:0.25054
# [12]	train-rmse:0.20729	validation-rmse:0.24791
# [13]	train-rmse:0.20318	validation-rmse:0.24628
# [14]	train-rmse:0.20135	validation-rmse:0.24630
# [15]	train-rmse:0.19858	validation-rmse:0.24523
# [16]	train-rmse:0.19580	validation-rmse:0.24445
# [17]	train-rmse:0.19333	validation-rmse:0.24395
# [18]	train-rmse:0.19107	validation-rmse:0.24284
# [19]	train-rmse:0.18735	validation-rmse:0.24127
# [20]	train-rmse:0.18524	validation-rmse:0.23978
# [21]	train-rmse:0.18332	validation-rmse:0.23963
# [22]	train-rmse:0.18189	validation-rmse:0.23892
# [23]	train-rmse:0.18006	validation-rmse:0.23847
# [24]	train-rmse:0.17869	validation-rmse:0.23847
# [25]	train-rmse:0.17757	validation-rmse:0.23830
# [26]	train-rmse:0.17520	validation-rmse:0.23862
# [27]	train-rmse:0.17430	validation-rmse:0.23807
# [28]	train-rmse:0.17281	validation-rmse:0.23793
# [29]	train-rmse:0.17091	validation-rmse:0.23684
# [30]	train-rmse:0.16888	validation-rmse:0.23571
# [31]	train-rmse:0.16727	validation-rmse:0.23505
# [32]	train-rmse:0.16553	validation-rmse:0.23494
# [33]	train-rmse:0.16453	validation-rmse:0.23476
# [34]	train-rmse:0.16292	validation-rmse:0.23490
# [35]	train-rmse:0.16113	validation-rmse:0.23416
# [36]	train-rmse:0.15969	validation-rmse:0.23402
# [37]	train-rmse:0.15859	validation-rmse:0.23362
# [38]	train-rmse:0.15726	validation-rmse:0.23393
# [39]	train-rmse:0.15663	validation-rmse:0.23383
# [40]	train-rmse:0.15542	validation-rmse:0.23319
# [41]	train-rmse:0.15426	validation-rmse:0.23300
# [42]	train-rmse:0.15289	validation-rmse:0.23266
# [43]	train-rmse:0.15189	validation-rmse:0.23252
# [44]	train-rmse:0.15092	validation-rmse:0.23252
# [45]	train-rmse:0.14941	validation-rmse:0.23190
# [46]	train-rmse:0.14857	validation-rmse:0.23178
# [47]	train-rmse:0.14742	validation-rmse:0.23183
# [48]	train-rmse:0.14683	validation-rmse:0.23198
# [49]	train-rmse:0.14629	validation-rmse:0.23206
# [50]	train-rmse:0.14536	validation-rmse:0.23225
# [51]	train-rmse:0.14450	validation-rmse:0.23225
# [52]	train-rmse:0.14353	validation-rmse:0.23223
# [53]	train-rmse:0.14276	validation-rmse:0.23199
# [54]	train-rmse:0.14180	validation-rmse:0.23194
# [55]	train-rmse:0.14150	validation-rmse:0.23197
# [56]	train-rmse:0.14085	validation-rmse:0.23189
# [57]	train-rmse:0.14020	validation-rmse:0.23178
# [58]	train-rmse:0.13931	validation-rmse:0.23176
# [59]	train-rmse:0.13817	validation-rmse:0.23148
# [60]	train-rmse:0.13719	validation-rmse:0.23139
# [61]	train-rmse:0.13640	validation-rmse:0.23179
# [62]	train-rmse:0.13566	validation-rmse:0.23161
# [63]	train-rmse:0.13439	validation-rmse:0.23151
# [64]	train-rmse:0.13359	validation-rmse:0.23154
# [65]	train-rmse:0.13260	validation-rmse:0.23158
# [66]	train-rmse:0.13197	validation-rmse:0.23144
# [67]	train-rmse:0.13175	validation-rmse:0.23148
# [68]	train-rmse:0.13117	validation-rmse:0.23148
# [69]	train-rmse:0.13046	validation-rmse:0.23137
# [70]	train-rmse:0.12943	validation-rmse:0.23068
# [71]	train-rmse:0.12894	validation-rmse:0.23064
# [72]	train-rmse:0.12854	validation-rmse:0.23082
# [73]	train-rmse:0.12741	validation-rmse:0.23059
# [74]	train-rmse:0.12635	validation-rmse:0.23048
# [75]	train-rmse:0.12555	validation-rmse:0.23039
# [76]	train-rmse:0.12395	validation-rmse:0.22935
# [77]	train-rmse:0.12342	validation-rmse:0.22942
# [78]	train-rmse:0.12255	validation-rmse:0.22913
# [79]	train-rmse:0.12220	validation-rmse:0.22889
# [80]	train-rmse:0.12192	validation-rmse:0.22886
# [81]	train-rmse:0.12126	validation-rmse:0.22903
# [82]	train-rmse:0.12056	validation-rmse:0.22892
# [83]	train-rmse:0.11995	validation-rmse:0.22885
# [84]	train-rmse:0.11922	validation-rmse:0.22893
# [85]	train-rmse:0.11854	validation-rmse:0.22888
# [86]	train-rmse:0.11781	validation-rmse:0.22899
# [87]	train-rmse:0.11692	validation-rmse:0.22908
# [88]	train-rmse:0.11613	validation-rmse:0.22905
# [89]	train-rmse:0.11557	validation-rmse:0.22886
# [90]	train-rmse:0.11504	validation-rmse:0.22877
# [91]	train-rmse:0.11440	validation-rmse:0.22873
# [92]	train-rmse:0.11383	validation-rmse:0.22886
# [93]	train-rmse:0.11353	validation-rmse:0.22878
# [94]	train-rmse:0.11289	validation-rmse:0.22871
# [95]	train-rmse:0.11266	validation-rmse:0.22865
# [96]	train-rmse:0.11223	validation-rmse:0.22861
# [97]	train-rmse:0.11170	validation-rmse:0.22860
# [98]	train-rmse:0.11101	validation-rmse:0.22872
# [99]	train-rmse:0.11043	validation-rmse:0.22873

# %%
xgb_num_rounds = 100
xgb_params = {
    'eta': 0.1,
    'max_depth': 6,
    'min_child_weight': 1,

    'objective': 'reg:squarederror',
    'nthread': 8,

    'seed': 1,
    'verbosity': 1,
}

model_eta1 = xgb.train(xgb_params, dtrain, xgb_num_rounds, evals=watchlist)
# Out:
# [0]	train-rmse:0.52449	validation-rmse:0.52045
# [1]	train-rmse:0.48736	validation-rmse:0.48443
# [2]	train-rmse:0.45433	validation-rmse:0.45293
# [3]	train-rmse:0.42534	validation-rmse:0.42550
# [4]	train-rmse:0.39987	validation-rmse:0.40144
# [5]	train-rmse:0.37823	validation-rmse:0.38152
# [6]	train-rmse:0.35887	validation-rmse:0.36393
# [7]	train-rmse:0.34177	validation-rmse:0.34838
# [8]	train-rmse:0.32701	validation-rmse:0.33492
# [9]	train-rmse:0.31412	validation-rmse:0.32333
# [10]	train-rmse:0.30326	validation-rmse:0.31427
# [11]	train-rmse:0.29356	validation-rmse:0.30615
# [12]	train-rmse:0.28520	validation-rmse:0.29922
# [13]	train-rmse:0.27760	validation-rmse:0.29269
# [14]	train-rmse:0.27116	validation-rmse:0.28797
# [15]	train-rmse:0.26539	validation-rmse:0.28380
# [16]	train-rmse:0.26013	validation-rmse:0.27970
# [17]	train-rmse:0.25583	validation-rmse:0.27662
# [18]	train-rmse:0.25203	validation-rmse:0.27388
# [19]	train-rmse:0.24818	validation-rmse:0.27124
# [20]	train-rmse:0.24512	validation-rmse:0.26882
# [21]	train-rmse:0.24150	validation-rmse:0.26669
# [22]	train-rmse:0.23895	validation-rmse:0.26479
# [23]	train-rmse:0.23594	validation-rmse:0.26332
# [24]	train-rmse:0.23305	validation-rmse:0.26141
# [25]	train-rmse:0.23027	validation-rmse:0.25997
# [26]	train-rmse:0.22721	validation-rmse:0.25799
# [27]	train-rmse:0.22488	validation-rmse:0.25620
# [28]	train-rmse:0.22268	validation-rmse:0.25494
# [29]	train-rmse:0.22084	validation-rmse:0.25374
# [30]	train-rmse:0.21887	validation-rmse:0.25267
# [31]	train-rmse:0.21709	validation-rmse:0.25172
# [32]	train-rmse:0.21505	validation-rmse:0.25075
# [33]	train-rmse:0.21342	validation-rmse:0.24991
# [34]	train-rmse:0.21168	validation-rmse:0.24882
# [35]	train-rmse:0.21020	validation-rmse:0.24827
# [36]	train-rmse:0.20879	validation-rmse:0.24779
# [37]	train-rmse:0.20755	validation-rmse:0.24731
# [38]	train-rmse:0.20625	validation-rmse:0.24668
# [39]	train-rmse:0.20518	validation-rmse:0.24624
# [40]	train-rmse:0.20392	validation-rmse:0.24539
# [41]	train-rmse:0.20286	validation-rmse:0.24501
# [42]	train-rmse:0.20172	validation-rmse:0.24435
# [43]	train-rmse:0.20045	validation-rmse:0.24380
# [44]	train-rmse:0.19900	validation-rmse:0.24311
# [45]	train-rmse:0.19814	validation-rmse:0.24293
# [46]	train-rmse:0.19628	validation-rmse:0.24184
# [47]	train-rmse:0.19562	validation-rmse:0.24159
# [48]	train-rmse:0.19464	validation-rmse:0.24131
# [49]	train-rmse:0.19372	validation-rmse:0.24109
# [50]	train-rmse:0.19215	validation-rmse:0.24020
# [51]	train-rmse:0.19156	validation-rmse:0.24015
# [52]	train-rmse:0.19060	validation-rmse:0.23979
# [53]	train-rmse:0.18985	validation-rmse:0.23958
# [54]	train-rmse:0.18932	validation-rmse:0.23930
# [55]	train-rmse:0.18809	validation-rmse:0.23878
# [56]	train-rmse:0.18734	validation-rmse:0.23853
# [57]	train-rmse:0.18681	validation-rmse:0.23849
# [58]	train-rmse:0.18623	validation-rmse:0.23836
# [59]	train-rmse:0.18561	validation-rmse:0.23835
# [60]	train-rmse:0.18457	validation-rmse:0.23791
# [61]	train-rmse:0.18363	validation-rmse:0.23783
# [62]	train-rmse:0.18310	validation-rmse:0.23788
# [63]	train-rmse:0.18210	validation-rmse:0.23755
# [64]	train-rmse:0.18150	validation-rmse:0.23735
# [65]	train-rmse:0.18064	validation-rmse:0.23698
# [66]	train-rmse:0.17999	validation-rmse:0.23682
# [67]	train-rmse:0.17913	validation-rmse:0.23646
# [68]	train-rmse:0.17843	validation-rmse:0.23628
# [69]	train-rmse:0.17798	validation-rmse:0.23628
# [70]	train-rmse:0.17741	validation-rmse:0.23622
# [71]	train-rmse:0.17685	validation-rmse:0.23608
# [72]	train-rmse:0.17617	validation-rmse:0.23584
# [73]	train-rmse:0.17557	validation-rmse:0.23562
# [74]	train-rmse:0.17522	validation-rmse:0.23537
# [75]	train-rmse:0.17468	validation-rmse:0.23510
# [76]	train-rmse:0.17433	validation-rmse:0.23504
# [77]	train-rmse:0.17395	validation-rmse:0.23494
# [78]	train-rmse:0.17334	validation-rmse:0.23482
# [79]	train-rmse:0.17287	validation-rmse:0.23467
# [80]	train-rmse:0.17242	validation-rmse:0.23454
# [81]	train-rmse:0.17213	validation-rmse:0.23447
# [82]	train-rmse:0.17139	validation-rmse:0.23431
# [83]	train-rmse:0.17105	validation-rmse:0.23428
# [84]	train-rmse:0.17063	validation-rmse:0.23413
# [85]	train-rmse:0.17014	validation-rmse:0.23404
# [86]	train-rmse:0.16966	validation-rmse:0.23401
# [87]	train-rmse:0.16916	validation-rmse:0.23388
# [88]	train-rmse:0.16883	validation-rmse:0.23365
# [89]	train-rmse:0.16835	validation-rmse:0.23340
# [90]	train-rmse:0.16798	validation-rmse:0.23332
# [91]	train-rmse:0.16756	validation-rmse:0.23330
# [92]	train-rmse:0.16708	validation-rmse:0.23298
# [93]	train-rmse:0.16623	validation-rmse:0.23273
# [94]	train-rmse:0.16586	validation-rmse:0.23280
# [95]	train-rmse:0.16562	validation-rmse:0.23276
# [96]	train-rmse:0.16524	validation-rmse:0.23266
# [97]	train-rmse:0.16444	validation-rmse:0.23246
# [98]	train-rmse:0.16384	validation-rmse:0.23222
# [99]	train-rmse:0.16323	validation-rmse:0.23209
